# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("part-m-00000", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data1 = pd.read_csv("part-m-00001", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data2 = pd.read_csv("part-m-00002", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data3 = pd.read_csv("part-m-00003", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data4 = pd.read_csv("part-m-00004", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data5 = pd.read_csv("part-m-00005", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data6 = pd.read_csv("part-m-00006", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data7 = pd.read_csv("part-m-00007", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data8 = pd.read_csv("part-m-00008", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data9 = pd.read_csv("part-m-00009", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data10 = pd.read_csv("part-m-00010", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data11 = pd.read_csv("part-m-00011", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data12 = pd.read_csv("part-m-00012", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data13 = pd.read_csv("part-m-00013", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data14 = pd.read_csv("part-m-00014", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data15 = pd.read_csv("part-m-00015", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data16 = pd.read_csv("part-m-00016", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data17 = pd.read_csv("part-m-00017", header=None, names=['allRideCount', 'allAverageRideTime', 'allAverageRideDistance', 
                                                       'recent1DayRideCount', 'rencent1DayAverageRideTime', 'recent1DayAverageDistance', 
                                                       'recent3DayRideCount', 'rencent3DayAverageRideTime', 'recent3DayAverageDistance',
                                                       'recent5DayRideCount', 'rencent5DayAverageRideTime', 'recent5DayAverageDistance',
                                                       'recent7DayRideCount', 'rencent7DayAverageRideTime', 'recent7DayAverageDistance',
                                                       'idleHour', 'serveDay', 'afterFault1HourRideCount', 'afterFault1HouraveTime', 
                                                       'afterFault2HourRideCount', 'afterFault2HouraveTime', 'afterFault3HourRideCount',
                                                       'afterFault3HouraveTime', 'afterFault6HourRideCount', 'afterFault6HouraveTime',
                                                       'afterFault12HourRideCount', 'afterFault12HouraveTime', 'afterFault24HourRideCount',
                                                       'afterFault24HouraveTime', 'reportFaultCount', 'correctFaultCount', 'processingFaultCount',
                                                       'typefixResult', 'bikefixResult'])

# %%
data_all = pd.concat([data,data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14,data15,data16,data17])

# %%
data_all.to_csv("data_all.csv", index=False)

# %%
data_all.describe()
# Out:
#         allRideCount  allAverageRideTime  allAverageRideDistance  \
# count  898017.000000       898017.000000            8.980170e+05
# mean      181.667297           13.510264            1.045229e+03
# std       131.462214           22.633202            8.676954e+03
# min         0.000000            0.000000            0.000000e+00
# 25%        77.000000           10.000000            7.210000e+02
# 50%       158.000000           12.000000            8.540000e+02
# 75%       262.000000           15.000000            9.990000e+02
# max      1787.000000         6752.000000            1.945128e+06
#
#        recent1DayRideCount  rencent1DayAverageRideTime  \
# count        898017.000000               898017.000000
# mean              6.172837                   12.108779
# std               6.886966                  143.899947
# min               0.000000                    0.000000
# 25%               2.000000                    1.000000
# ...

# %%
df = data_all.filter(regex="bikefixResult|typefixResult|afterFault6HouraveTime|afterFault6HourRideCount")

# %%
df.head()
# Out:
#    afterFault6HourRideCount  afterFault6HouraveTime  typefixResult  \
# 0                         0                       0              1
# 1                         5                       6              1
# 2                         3                       7              1
# 3                         3                      28              1
# 4                         0                       0              0
#
#    bikefixResult
# 0              1
# 1              1
# 2              1
# 3              1
# 4              0

# %%
df.typefixResult.value_counts()
# Out:
# 1    554896
# 0    343121
# Name: typefixResult, dtype: int64

# %%
df[(df.afterFault6HourRideCount >= 2) & (df.afterFault6HouraveTime >= 5)].typefixResult.value_counts()
# Out:
# 1    167317
# 0     48892
# Name: typefixResult, dtype: int64

# %%
167317/554896
# Out:
# 0.3015285747239122

# %%
48892/343121
# Out:
# 0.14249200719279786

# %%
0.3015285747239122/0.14249200719279786
# Out:
# 2.1161086903346864

# %%
554896+343121
# Out:
# 898017

# %%
np.log(525635*343083/(554683*319610))
# Out:
# 0.017081174007811537

# %%
np.log((5695/554683)/(2565/343083))
# Out:
# 0.3172057392817256

# %%
np.log(1.373)
# Out:
# 0.316998126785834

# %%
np.log((1/554683)/(1/343083))
# Out:
# -0.4804243789946872

# %%
data_201803 = pd.read_csv("tmp201803", header=None, names=["allCounts", "faultCounts", "trueCounts",  
                                                "faultOrder", "trueOrder", "faultWordLength", "trueWordLength", 
                                                "faultType0", "faultType1", "faultType2", "faultType3", "faultType4",
                                                "faultType5", "faultType6", "faultType7", "faultType10", "faultType11",
                                               "faultType12", "faultType13", "faultType14", "faultType15", "faultType16",
                                               "faultType17", "faultType18", "faultType101", "faultType102", "faultType103",
                                               "faultType104", "faultType105", "faultType106", "faultType107", "faultType108",
                                               "faultType109", "faultType110", "faultType111", "faultType112", "faultType113",
                                               "faultType201", "faultType202", "faultType203", "faultType204", "faultType205",
                                               "trueType0", "trueType1", "trueType2", "trueType3", "trueType4",
                                                "trueType5", "trueType6", "trueType7", "trueType10", "trueType11",
                                               "trueType12", "trueType13", "trueType14", "trueType15", "trueType16",
                                               "trueType17", "trueType18", "trueType101", "trueType102", "trueType103",
                                               "trueType104", "trueType105", "trueType106", "trueType107", "trueType108",
                                               "trueType109", "trueType110", "trueType111", "trueType112", "trueType113",
                                               "trueType201", "trueType202", "trueType203", "trueType204", "trueType205"])

# %%
data_201803
# Out:
#    allCounts  faultCounts  trueCounts  faultOrder  trueOrder  faultWordLength  \
# 0     897766       554683      343083      525635     319610             5695
#
#    trueWordLength  faultType0  faultType1  faultType2     ...       \
# 0            2565           0           0           0     ...
#
#    trueType109  trueType110  trueType111  trueType112  trueType113  \
# 0        74664        22470        22644        66177        10599
#
#    trueType201  trueType202  trueType203  trueType204  trueType205
# 0          372            0            0            5            0
#
# [1 rows x 77 columns]

# %%
data_201803["resultOrder"] = (data_201803.faultOrder/data_201803.faultCounts) / (data_201803.trueOrder/data_201803.trueCounts)

# %%
data_201803
# Out:
#    allCounts  faultCounts  trueCounts  faultOrder  trueOrder  faultWordLength  \
# 0     897766       554683      343083      525635     319610             5695
#
#    trueWordLength  faultType0  faultType1  faultType2        ...         \
# 0            2565           0           0           0        ...
#
#    trueType111  trueType112  trueType113  trueType201  trueType202  \
# 0        22644        66177        10599          372            0
#
#    trueType203  trueType204  trueType205  resultOrder  resultWordLength
# 0            0            5            0     1.017228          1.373285
#
# [1 rows x 79 columns]

# %%
data_201803["resultWordLength"] = (data_201803.faultWordLength/data_201803.faultCounts) / (data_201803.trueWordLength/data_201803.trueCounts)

# %%
data_201803["resultType0"] = (data_201803.faultType0/data_201803.faultCounts) / (data_201803.trueType0/data_201803.trueCounts)
data_201803["resultType1"] = (data_201803.faultType1/data_201803.faultCounts) / (data_201803.trueType1/data_201803.trueCounts)
data_201803["resultType2"] = (data_201803.faultType2/data_201803.faultCounts) / (data_201803.trueType2/data_201803.trueCounts)
data_201803["resultType3"] = (data_201803.faultType3/data_201803.faultCounts) / (data_201803.trueType3/data_201803.trueCounts)
data_201803["resultType4"] = (data_201803.faultType4/data_201803.faultCounts) / (data_201803.trueType4/data_201803.trueCounts)
data_201803["resultType5"] = (data_201803.faultType5/data_201803.faultCounts) / (data_201803.trueType5/data_201803.trueCounts)
data_201803["resultType6"] = (data_201803.faultType6/data_201803.faultCounts) / (data_201803.trueType6/data_201803.trueCounts)
data_201803["resultType10"] = (data_201803.faultType10/data_201803.faultCounts) / (data_201803.trueType10/data_201803.trueCounts)
data_201803["resultType11"] = (data_201803.faultType11/data_201803.faultCounts) / (data_201803.trueType11/data_201803.trueCounts)
data_201803["resultType12"] = (data_201803.faultType12/data_201803.faultCounts) / (data_201803.trueType12/data_201803.trueCounts)
data_201803["resultType13"] = (data_201803.faultType13/data_201803.faultCounts) / (data_201803.trueType13/data_201803.trueCounts)
data_201803["resultType14"] = (data_201803.faultType14/data_201803.faultCounts) / (data_201803.trueType14/data_201803.trueCounts)
data_201803["resultType15"] = (data_201803.faultType15/data_201803.faultCounts) / (data_201803.trueType15/data_201803.trueCounts)
data_201803["resultType16"] = (data_201803.faultType16/data_201803.faultCounts) / (data_201803.trueType16/data_201803.trueCounts)
data_201803["resultType17"] = (data_201803.faultType17/data_201803.faultCounts) / (data_201803.trueType17/data_201803.trueCounts)
data_201803["resultType18"] = (data_201803.faultType18/data_201803.faultCounts) / (data_201803.trueType18/data_201803.trueCounts)
data_201803["resultType101"] = (data_201803.faultType101/data_201803.faultCounts) / (data_201803.trueType101/data_201803.trueCounts)
data_201803["resultType102"] = (data_201803.faultType102/data_201803.faultCounts) / (data_201803.trueType102/data_201803.trueCounts)
data_201803["resultType103"] = (data_201803.faultType103/data_201803.faultCounts) / (data_201803.trueType103/data_201803.trueCounts)
data_201803["resultType104"] = (data_201803.faultType104/data_201803.faultCounts) / (data_201803.trueType104/data_201803.trueCounts)
data_201803["resultType105"] = (data_201803.faultType105/data_201803.faultCounts) / (data_201803.trueType105/data_201803.trueCounts)
data_201803["resultType106"] = (data_201803.faultType106/data_201803.faultCounts) / (data_201803.trueType106/data_201803.trueCounts)
data_201803["resultType107"] = (data_201803.faultType107/data_201803.faultCounts) / (data_201803.trueType107/data_201803.trueCounts)
data_201803["resultType108"] = (data_201803.faultType108/data_201803.faultCounts) / (data_201803.trueType108/data_201803.trueCounts)
data_201803["resultType109"] = (data_201803.faultType109/data_201803.faultCounts) / (data_201803.trueType109/data_201803.trueCounts)
data_201803["resultType110"] = (data_201803.faultType110/data_201803.faultCounts) / (data_201803.trueType110/data_201803.trueCounts)
data_201803["resultType111"] = (data_201803.faultType111/data_201803.faultCounts) / (data_201803.trueType111/data_201803.trueCounts)
data_201803["resultType112"] = (data_201803.faultType112/data_201803.faultCounts) / (data_201803.trueType112/data_201803.trueCounts)
data_201803["resultType113"] = (data_201803.faultType113/data_201803.faultCounts) / (data_201803.trueType113/data_201803.trueCounts)
data_201803["resultType201"] = (data_201803.faultType201/data_201803.faultCounts) / (data_201803.trueType201/data_201803.trueCounts)
data_201803["resultType202"] = (data_201803.faultType202/data_201803.faultCounts) / (data_201803.trueType202/data_201803.trueCounts)
data_201803["resultType203"] = (data_201803.faultType203/data_201803.faultCounts) / (data_201803.trueType203/data_201803.trueCounts)
data_201803["resultType204"] = (data_201803.faultType204/data_201803.faultCounts) / (data_201803.trueType204/data_201803.trueCounts)
data_201803["resultType205"] = (data_201803.faultType205/data_201803.faultCounts) / (data_201803.trueType205/data_201803.trueCounts)

# %%
result_data = data_201803.filter(regex="result.*")

# %%
f1 = np.log(result_data)

# %%
f1.to_csv("result_model.csv", index=False)
