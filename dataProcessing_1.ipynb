# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data.csv", header=0)

# %%
df = data.filter(regex="result.*")

# %%
df.head()
# Out:
#    resultType113  resultType201  resultType202  resultType203  resultType204  \
# 0       1.411422       0.093767       0.000000       0.000000       0.084838
# 1       1.695312       0.186597       0.000000       0.000000       0.070555
# 2       1.386924       0.319396       0.000000       0.000000       0.136097
# 3       0.737545       1.586991       0.447124       0.655781       0.493754
# 4       0.490547       3.075137       0.014269       0.428075       0.151085
#
#    resultType205  resultType0  resultType1  resultType2  resultType3  \
# 0       0.001153          NaN          NaN     0.000000     8.628040
# 1       0.015495          NaN          NaN     0.000000          inf
# 2       0.072847          NaN          NaN     0.000000     1.720659
# 3       0.310503          NaN          NaN     0.819727     0.409863
# 4       0.160699          NaN          NaN     0.642113     1.783647
#
#       ...       resultType105  resultType106  resultType107  resultType108  \
# ...

# %%
df2 = np.log(df)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#    resultType113  resultType201  resultType202  resultType203  resultType204  \
# 0       0.344598      -2.366944           -inf           -inf      -2.467010
# 1       0.527867      -1.678803           -inf           -inf      -2.651356
# 2       0.327088      -1.141325           -inf           -inf      -1.994385
# 3      -0.304429       0.461840      -0.804920      -0.421928      -0.705719
# 4      -0.712234       1.123349      -4.249654      -0.848456      -1.889910
#
#    resultType205  resultType0  resultType1  resultType2  resultType3  \
# 0      -6.765078          NaN          NaN         -inf     2.155017
# 1      -4.167216          NaN          NaN         -inf          inf
# 2      -2.619397          NaN          NaN         -inf     0.542707
# 3      -1.169563          NaN          NaN    -0.198784    -0.891931
# 4      -1.828221          NaN          NaN    -0.442991     0.578660
#
#       ...       resultType105  resultType106  resultType107  resultType108  \
# ...

# %%
df2
