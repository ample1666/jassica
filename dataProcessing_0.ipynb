# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("frank", header=None, names=["allCounts", "faultCounts", "trueCounts", "faultMaint", "trueMaint", 
                                                "faultOrder", "trueOrder", "faultWordLength", "trueWordLength", 
                                                "faultType0", "faultType1", "faultType2", "faultType3", "faultType4",
                                                "faultType5", "faultType6", "faultType7", "faultType10", "faultType11",
                                               "faultType12", "faultType13", "faultType14", "faultType15", "faultType16",
                                               "faultType17", "faultType18", "faultType101", "faultType102", "faultType103",
                                               "faultType104", "faultType105", "faultType106", "faultType107", "faultType108",
                                               "faultType109", "faultType110", "faultType111", "faultType112", "faultType113",
                                               "faultType201", "faultType202", "faultType203", "faultType204", "faultType205",
                                               "trueType0", "trueType1", "trueType2", "trueType3", "trueType4",
                                                "trueType5", "trueType6", "trueType7", "trueType10", "trueType11",
                                               "trueType12", "trueType13", "trueType14", "trueType15", "trueType16",
                                               "trueType17", "trueType18", "trueType101", "trueType102", "trueType103",
                                               "trueType104", "trueType105", "trueType106", "trueType107", "trueType108",
                                               "trueType109", "trueType110", "trueType111", "trueType112", "trueType113",
                                               "trueType201", "trueType202", "trueType203", "trueType204", "trueType205"])

# %%
data.head()
# Out:
#    allCounts  faultCounts  trueCounts  faultMaint  trueMaint  faultOrder  \
# 0    1313946       764365      549581      554683     343083      735193
# 1     565018       287963      277055      206217     119217      273166
# 2     628596       337895      290701      235565     138490      316549
# 3     775047       501167      273880      302691     189442      468406
# 4     463043       281980      181063      139144     138129      271310
#
#    trueOrder  faultWordLength  trueWordLength  faultType0     ...       \
# 0     502595             5775            9665           0     ...
# 1     244207             2742            7359           0     ...
# 2     249590             4874            9880           0     ...
# 3     241390            13381            7440           0     ...
# 4     166353             7543            4832           0     ...
#
#    trueType109  trueType110  trueType111  trueType112  trueType113  \
# ...

# %%
ax = data.allCounts.plot()
fig = ax.get_figure()
fig.savefig('allCounts.png')

# %%
ax = data.faultCounts.plot()
fig = ax.get_figure()
fig.savefig('faultCounts.png')

# %%
ax = data.trueCounts.plot()
fig = ax.get_figure()
fig.savefig('trueCounts.png')

# %%
ax = data.faultMaint.plot()
fig = ax.get_figure()
fig.savefig('faultMaint.png')

# %%
ax = data.trueMaint.plot()
fig = ax.get_figure()
fig.savefig('trueMaint.png')

# %%
data["faultWordLengthRadio"] = data.faultWordLength / data.faultCounts
data["trueWordLengthRadio"] = data.trueWordLength / data.trueCounts

# %%
data["faultType0Ratio"] = data.faultType0 / data.faultCounts
data["trueType0Ratio"] = data.trueType0 / data.trueCounts

# %%
data["faultType1Ratio"] = data.faultType1 / data.faultCounts
data["trueType1Ratio"] = data.trueType1 / data.trueCounts

# %%
data["faultType2Ratio"] = data.faultType2 / data.faultCounts
data["trueType2Ratio"] = data.trueType2 / data.trueCounts

# %%
data["faultType3Ratio"] = data.faultType3 / data.faultCounts
data["trueType3Ratio"] = data.trueType3 / data.trueCounts

# %%
data["faultType4Ratio"] = data.faultType4 / data.faultCounts
data["trueType4Ratio"] = data.trueType4 / data.trueCounts

# %%
data["faultType5Ratio"] = data.faultType5 / data.faultCounts
data["trueType5Ratio"] = data.trueType5 / data.trueCounts

# %%
data["faultType6Ratio"] = data.faultType6 / data.faultCounts
data["trueType6Ratio"] = data.trueType6 / data.trueCounts

# %%
data["faultType7Ratio"] = data.faultType7 / data.faultCounts
data["trueType7Ratio"] = data.trueType7 / data.trueCounts

# %%
data["faultType10Ratio"] = data.faultType10 / data.faultCounts
data["trueType10Ratio"] = data.trueType10 / data.trueCounts

# %%
data["faultType11Ratio"] = data.faultType11 / data.faultCounts
data["trueType11Ratio"] = data.trueType11 / data.trueCounts

# %%
data["faultType12Ratio"] = data.faultType12 / data.faultCounts
data["trueType12Ratio"] = data.trueType12 / data.trueCounts

# %%
data["faultType13Ratio"] = data.faultType13 / data.faultCounts
data["trueType13Ratio"] = data.trueType13 / data.trueCounts

# %%
data["faultType14Ratio"] = data.faultType14 / data.faultCounts
data["trueType14Ratio"] = data.trueType14 / data.trueCounts

# %%
data["faultType15Ratio"] = data.faultType15 / data.faultCounts
data["trueType15Ratio"] = data.trueType15 / data.trueCounts

# %%
data["faultType16Ratio"] = data.faultType16 / data.faultCounts
data["trueType16Ratio"] = data.trueType16 / data.trueCounts

# %%
data["faultType17Ratio"] = data.faultType17 / data.faultCounts
data["trueType17Ratio"] = data.trueType17 / data.trueCounts

# %%
data["faultType18Ratio"] = data.faultType18 / data.faultCounts
data["trueType18Ratio"] = data.trueType18 / data.trueCounts

# %%
data["faultType101Ratio"] = data.faultType101 / data.faultCounts
data["trueType101Ratio"] = data.trueType101 / data.trueCounts

# %%
data["faultType102Ratio"] = data.faultType102 / data.faultCounts
data["trueType102Ratio"] = data.trueType102 / data.trueCounts

# %%
data["faultType103Ratio"] = data.faultType103 / data.faultCounts
data["trueType103Ratio"] = data.trueType103 / data.trueCounts

# %%
data["faultType104Ratio"] = data.faultType104 / data.faultCounts
data["trueType104Ratio"] = data.trueType104 / data.trueCounts

# %%
data["faultType105Ratio"] = data.faultType105 / data.faultCounts
data["trueType105Ratio"] = data.trueType105 / data.trueCounts

# %%
data["faultType106Ratio"] = data.faultType106 / data.faultCounts
data["trueType106Ratio"] = data.trueType106 / data.trueCounts

# %%
data["faultType107Ratio"] = data.faultType107 / data.faultCounts
data["trueType107Ratio"] = data.trueType107 / data.trueCounts

# %%
data["faultType108Ratio"] = data.faultType108 / data.faultCounts
data["trueType108Ratio"] = data.trueType108 / data.trueCounts

# %%
data["faultType109Ratio"] = data.faultType109 / data.faultCounts
data["trueType109Ratio"] = data.trueType109 / data.trueCounts

# %%
data["faultType110Ratio"] = data.faultType110 / data.faultCounts
data["trueType110Ratio"] = data.trueType110 / data.trueCounts

# %%
data["faultType111Ratio"] = data.faultType111 / data.faultCounts
data["trueType111Ratio"] = data.trueType111 / data.trueCounts

# %%
data["faultType112Ratio"] = data.faultType112 / data.faultCounts
data["trueType112Ratio"] = data.trueType112 / data.trueCounts

# %%
data["faultType113Ratio"] = data.faultType113 / data.faultCounts
data["trueType113Ratio"] = data.trueType113 / data.trueCounts
data["resultType113"] = data.faultType113Ratio / data.trueType113Ratio #（如果结果落在（0.5，2）之间，则表示Type没有区分度

# %%
data["faultType201Ratio"] = data.faultType201 / data.faultCounts
data["trueType201Ratio"] = data.trueType201 / data.trueCounts
data["resultType201"] = data.faultType201Ratio / data.trueType201Ratio #如果结果落在（0.5，2）之间，则表示Type没有区分度;如果结果小于0.5，则是正确报障，如果结果大于2，则是误报

# %%
data["faultType202Ratio"] = data.faultType202 / data.faultCounts
data["trueType202Ratio"] = data.trueType202 / data.trueCounts
data["resultType202"] = data.faultType202Ratio / data.trueType202Ratio #如果结果落在（0.5，2）之间，则表示Type没有区分度;如果结果小于0.5，则是正确报障，如果结果大于2，则是误报

# %%
data["faultType203Ratio"] = data.faultType203 / data.faultCounts
data["trueType203Ratio"] = data.trueType203 / data.trueCounts
data["resultType203"] = data.faultType203Ratio / data.trueType203Ratio #如果结果落在（0.5，2）之间，则表示Type没有区分度;如果结果小于0.5，则是正确报障，如果结果大于2，则是误报

# %%
data["faultType204Ratio"] = data.faultType204 / data.faultCounts
data["trueType204Ratio"] = data.trueType204 / data.trueCounts
data["resultType204"] = data.faultType204Ratio / data.trueType204Ratio #如果结果落在（0.5，2）之间，则表示Type没有区分度;如果结果小于0.5，则是正确报障，如果结果大于2，则是误报

# %%
data["faultType205Ratio"] = data.faultType205 / data.faultCounts
data["trueType205Ratio"] = data.trueType205 / data.trueCounts
data["resultType205"] = data.faultType205Ratio / data.trueType205Ratio #如果结果落在（0.5，2）之间，则表示Type没有区分度;如果结果小于0.5，则是正确报障，如果结果大于2，则是误报

# %%
data["resultType0"] = data.faultType0Ratio / data.trueType0Ratio #如果结果落在（0.5，2）之间，则表示Type没有区分度;如果结果小于0.5，则是正确报障，如果结果大于2，则是误报

# %%
data["resultType1"] = data.faultType1Ratio / data.trueType1Ratio
data["resultType2"] = data.faultType2Ratio / data.trueType2Ratio
data["resultType3"] = data.faultType3Ratio / data.trueType3Ratio
data["resultType4"] = data.faultType4Ratio / data.trueType4Ratio
data["resultType5"] = data.faultType5Ratio / data.trueType5Ratio
data["resultType6"] = data.faultType6Ratio / data.trueType6Ratio
data["resultType7"] = data.faultType7Ratio / data.trueType7Ratio

# %%
data["resultType10"] = data.faultType10Ratio / data.trueType10Ratio
data["resultType11"] = data.faultType11Ratio / data.trueType11Ratio
data["resultType12"] = data.faultType12Ratio / data.trueType12Ratio
data["resultType13"] = data.faultType13Ratio / data.trueType13Ratio
data["resultType14"] = data.faultType14Ratio / data.trueType14Ratio
data["resultType15"] = data.faultType15Ratio / data.trueType15Ratio
data["resultType16"] = data.faultType16Ratio / data.trueType16Ratio
data["resultType17"] = data.faultType17Ratio / data.trueType17Ratio
data["resultType18"] = data.faultType18Ratio / data.trueType18Ratio

# %%
data["resultType101"] = data.faultType101Ratio / data.trueType101Ratio
data["resultType102"] = data.faultType102Ratio / data.trueType102Ratio
data["resultType103"] = data.faultType103Ratio / data.trueType103Ratio
data["resultType104"] = data.faultType104Ratio / data.trueType104Ratio
data["resultType105"] = data.faultType105Ratio / data.trueType105Ratio
data["resultType106"] = data.faultType106Ratio / data.trueType106Ratio
data["resultType107"] = data.faultType107Ratio / data.trueType107Ratio
data["resultType108"] = data.faultType108Ratio / data.trueType108Ratio
data["resultType109"] = data.faultType109Ratio / data.trueType109Ratio
data["resultType110"] = data.faultType110Ratio / data.trueType110Ratio
data["resultType111"] = data.faultType111Ratio / data.trueType111Ratio
data["resultType112"] = data.faultType112Ratio / data.trueType112Ratio
data["resultType113"] = data.faultType113Ratio / data.trueType113Ratio

# %%
data.columns
# Out:
# Index(['allCounts', 'faultCounts', 'trueCounts', 'faultMaint', 'trueMaint',
#        'faultOrder', 'trueOrder', 'faultWordLength', 'trueWordLength',
#        'faultType0',
#        ...
#        'resultType103', 'resultType104', 'resultType105', 'resultType106',
#        'resultType107', 'resultType108', 'resultType109', 'resultType110',
#        'resultType111', 'resultType112'],
#       dtype='object', length=186)

# %%
df = data.filter(regex="resultType.*")

# %%
df.to_csv("resultType.csv", index=False)

# %%
df.describe()
# Out:
#        resultType113  resultType201  resultType202  resultType203  \
# count      15.000000      15.000000      12.000000      12.000000
# mean        0.800717       4.346247       0.174845       0.265951
# std         0.520005       4.422293       0.269157       0.342556
# min         0.153619       0.093767       0.000000       0.000000
# 25%         0.404865       1.826099       0.010702       0.000000
# 50%         0.564255       3.324227       0.094880       0.162674
# 75%         1.383617       5.033614       0.173243       0.367940
# max         1.695312      16.550025       0.924425       1.111704
#
#        resultType204  resultType205  resultType0  resultType1  resultType2  \
# count      15.000000      12.000000    10.000000     2.000000    15.000000
# mean        0.355958       0.431869     0.651419          inf     0.913261
# std         0.364724       0.549473     0.773145          NaN     0.864745
# ...

# %%
df2 = data.filter(regex="trueType.*.Ratio")

# %%
df2
# Out:
#     trueType0Ratio  trueType1Ratio  trueType2Ratio  trueType3Ratio  \
# 0         0.000000             0.0        0.000016        0.000002
# 1         0.000000             0.0        0.000007        0.000000
# 2         0.000000             0.0        0.000003        0.000014
# 3         0.000000             0.0        0.000007        0.000044
# 4         0.000000             0.0        0.000006        0.000050
# 5         0.000006             0.0        0.000019        0.000019
# 6         0.000059             0.0        0.000071        0.000000
# 7         0.000094             0.0        0.000025        0.000069
# 8         0.000563             0.0        0.000361        0.000462
# 9         0.001531             0.0        0.000418        0.001062
# 10        0.002204             0.0        0.000564        0.001851
# 11        0.018526             0.0        0.011512        0.004352
# 12        0.039391             0.0        0.024974        0.001372
# ...

# %%
data["resultWordLength"] = data.faultWordLengthRadio / data.trueWordLengthRadio

# %%
data["faultOrderRatio"] = data.faultOrder / data.faultCounts
data["trueOrderRatio"] = data.trueOrder / data.trueCounts
data["resultOrder"] = data.faultOrder / data.trueOrder

# %%
data.to_csv("data.csv", index=False)
