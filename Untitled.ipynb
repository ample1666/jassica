# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("201803TrainData.txt")

# %%
data.head()
# Out:
#        bikeNo       timeStamp                          userGuid  faultType  \
# 0  2100000064  20180331104334  a6cf99692e1945519b335510cd57ef28        111
# 1  2100000070  20180331161752  3a888b7ff5994ec29c2c355416895c3a        112
# 2  2100000094  20180316115546  7c06f81ca312407f8b1e5b1f9a3342f6        106
# 3  2100000110  20180315154604  987be31d982c4850a9b503d054c73a62        109
# 4  2100000208  20180331152134  bb7f976e6a4c4226ae923c13800aca11        104
#
#    desWordLen  hasOrderId  userRideCount  userRideTime  userIssueFaultCount  \
# 0           0           1              3        921000                    0
# 1           0           1              1       3866000                    0
# 2           0           1              0             0                    0
# 3           0           0             10       3149000                    0
# 4           0           1              1       1241000                    0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847918 entries, 0 to 847917
# Data columns (total 64 columns):
# bikeNo                             847918 non-null int64
# timeStamp                          847918 non-null int64
# userGuid                           847918 non-null object
# faultType                          847918 non-null int64
# desWordLen                         847918 non-null int64
# hasOrderId                         847918 non-null int64
# userRideCount                      847918 non-null int64
# userRideTime                       847918 non-null int64
# userIssueFaultCount                847918 non-null int64
# userConfirmedIssueFaultCount       847918 non-null int64
# userHasMonthCard                   847918 non-null bool
# allRideCount                       847918 non-null int64
# allAverageRideTime                 847918 non-null int64
# allAverageRideDistance             847918 non-null int64
# ...

# %%
data = data.drop(["userGuid", "userHasMonthCard"], axis=1)

# %%
data[data.afterFault24HourRideCount > 20].bikefixResult.value_counts().plot(kind="bar")
